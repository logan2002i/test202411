# %%
import cv2
import time
import tensorflow
import detect_face
import numpy as np

#----tensorflow version check
if tensorflow.__version__.startswith('1.'):
    import tensorflow as tf
else:
    import tensorflow.compat.v1 as tf
    tf.disable_v2_behavior()
print("Tensorflow version: ",tf.__version__)


def video_init(is_2_write=False,save_path=None):
    writer = None
    cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)
    height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)#default 480
    width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)#default 640

    # width = 480
    # height = 640
    # cap.set(cv2.CAP_PROP_FRAME_WIDTH, width)
    # cap.set(cv2.CAP_PROP_FRAME_HEIGHT, height)

    '''
    ref:https://docs.opencv.org/master/dd/d43/tutorial_py_video_display.html
    FourCC is a 4-byte code used to specify the video codec. 
    The list of available codes can be found in fourcc.org. 
    It is platform dependent. The following codecs work fine for me.
    In Fedora: DIVX, XVID, MJPG, X264, WMV1, WMV2. (XVID is more preferable. MJPG results in high size video. X264 gives very small size video)
    In Windows: DIVX (More to be tested and added)
    In OSX: MJPG (.mp4), DIVX (.avi), X264 (.mkv).
    FourCC code is passed as `cv.VideoWriter_fourcc('M','J','P','G')or cv.VideoWriter_fourcc(*'MJPG')` for MJPG.
    '''

    if is_2_write is True:
        #fourcc = cv2.VideoWriter_fourcc('x', 'v', 'i', 'd')
        #fourcc = cv2.VideoWriter_fourcc('X', 'V', 'I', 'D')
        fourcc = cv2.VideoWriter_fourcc(*'divx')
        if save_path is None:
            save_path = 'demo.avi'
        writer = cv2.VideoWriter(save_path, fourcc, 30, (int(width), int(height)))

    return cap,height,width,writer

def face_detection_MTCNN(detect_multiple_faces=False):
    #----var
    frame_count = 0
    FPS = "Initialing"
    no_face_str = "No faces detected"

    #----video streaming init
    cap, height, width, writer = video_init(is_2_write=False)

    #----MTCNN init
    color = (0,255,0)
    minsize = 20  # minimum size of face
    threshold = [0.6, 0.7, 0.7]  # three steps's threshold
    factor = 0.709  # scale factor
    with tf.Graph().as_default():
        config = tf.ConfigProto(log_device_placement=True,
                                allow_soft_placement=True,  # 允許當找不到設備時自動轉換成有支援的設備
                                )
        # config.gpu_options.allow_growth = True
        config.gpu_options.per_process_gpu_memory_fraction = 0.1
        sess = tf.Session(config=config)
        with sess.as_default():
            pnet, rnet, onet = detect_face.create_mtcnn(sess, None)

    count = 0
    while (cap.isOpened()):

        #----get image
        ret, img = cap.read()

        if ret is True:
            #----image processing
            img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            print("image shape:",img_rgb.shape)

            #----face detection
            t_1 = time.time()
            bounding_boxes, points = detect_face.detect_face(img_rgb, minsize, pnet, rnet, onet, threshold, factor)
            d_t = time.time() - t_1
            print("Time of face detection: ",d_t)

            #----bounding boxes processing
            nrof_faces = bounding_boxes.shape[0]
            if nrof_faces > 0:
                points = np.array(points)
                points = np.transpose(points, [1, 0])
                points = points.astype(np.int16)

                det = bounding_boxes[:, 0:4]
                det_arr = []
                img_size = np.asarray(img.shape)[0:2]
                if nrof_faces > 1:
                    if detect_multiple_faces:
                        for i in range(nrof_faces):
                            det_arr.append(np.squeeze(det[i]))
                    else:
                        bounding_box_size = (det[:, 2] - det[:, 0]) * (det[:, 3] - det[:, 1])
                        img_center = img_size / 2
                        offsets = np.vstack(
                            [(det[:, 0] + det[:, 2]) / 2 - img_center[1], (det[:, 1] + det[:, 3]) / 2 - img_center[0]])
                        offset_dist_squared = np.sum(np.power(offsets, 2.0), 0)
                        index = np.argmax(
                            bounding_box_size - offset_dist_squared * 2.0)  # some extra weight on the centering
                        det_arr.append(det[index, :])
                else:
                    det_arr.append(np.squeeze(det))

                det_arr = np.array(det_arr)
                det_arr = det_arr.astype(np.int16)

                for i, det in enumerate(det_arr):
                    #det = det.astype(np.int32)
#                     cv2.rectangle(img, (det[0],det[1]), (det[2],det[3]), color, 2)
#                     print(det[0],det[1])
#                     print(det[2],det[3])
                    if nrof_faces > 0:
                        count+=1
                        file_name_path = './Dataset/Allne_0726/' + str(count) + '.jpg'
                        crop_img = img[det[1]-20:det[0]+30, det[3]-20:det[2]+30]
                        crop_img = cv2.resize(crop_img, (250, 250), interpolation=cv2.INTER_AREA)
#                         cv2.imwrite(file_name_path, crop_img)
                        cv2.imwrite(file_name_path, img)
#                       
                    #----draw 5 point on tha face
                    facial_points = points[i]
                    for j in range(0,5,1):
                        #cv2.circle(影像, 圓心座標, 半徑, 顏色, 線條寬度)
                        cv2.circle(img, (facial_points[j], facial_points[j + 5]), 2, (0, 0, 255), -1, 1)

            # ----no faces detected
            else:
                cv2.putText(img, no_face_str, (10, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)


            #----FPS count
            if frame_count == 0:
                t_start = time.time()
            frame_count += 1
            if frame_count >= 20:
                FPS = "FPS=%1f" % (frame_count / (time.time() - t_start))
                frame_count = 0

            # cv2.putText(影像, 文字, 座標, 字型, 大小, 顏色, 線條寬度, 線條種類)
            cv2.putText(img, FPS, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 3)

            #----image display
            cv2.imshow("臉擺好來!!!", img)

            #----image writing
            if writer is not None:
                writer.write(img)

            #----'q' key pressed?
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
            if count == 10:
                break
        else:
            print("get image failed")
            break

    #----release
    cap.release()
    if writer is not None:
        writer.release()
    cv2.destroyAllWindows()


if __name__ == "__main__":
    face_detection_MTCNN(detect_multiple_faces=False)
# Out:
# Tensorflow version:  1.15.0
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce RTX 2080, pci bus id: 0000:02:00.0, compute capability: 7.5
#
# image shape: (480, 640, 3)
# Time of face detection:  0.2461414337158203
# image shape: (480, 640, 3)
# Time of face detection:  0.054025888442993164
# image shape: (480, 640, 3)
# Time of face detection:  0.05666923522949219
# image shape: (480, 640, 3)
# Time of face detection:  0.051720619201660156
# image shape: (480, 640, 3)
# Time of face detection:  0.05036139488220215
# image shape: (480, 640, 3)
# Time of face detection:  0.05180859565734863
# image shape: (480, 640, 3)
# Time of face detection:  0.05468392372131348
# image shape: (480, 640, 3)
# Time of face detection:  0.05063033103942871
# image shape: (480, 640, 3)
# Time of face detection:  0.05108308792114258
# image shape: (480, 640, 3)
# Time of face detection:  0.05122089385986328
# image shape: (480, 640, 3)
# Time of face detection:  0.06228375434875488
# image shape: (480, 640, 3)
# Time of face detection:  0.05237603187561035
# image shape: (480, 640, 3)
# Time of face detection:  0.05105853080749512
# image shape: (480, 640, 3)
# Time of face detection:  0.05403423309326172
# image shape: (480, 640, 3)
# Time of face detection:  0.05232596397399902
# image shape: (480, 640, 3)
# Time of face detection:  0.04912972450256348
# image shape: (480, 640, 3)
# Time of face detection:  0.052121877670288086
# image shape: (480, 640, 3)
# Time of face detection:  0.06059670448303223
# image shape: (480, 640, 3)
# Time of face detection:  0.06711149215698242
# image shape: (480, 640, 3)
# Time of face detection:  0.07418227195739746
# image shape: (480, 640, 3)
# Time of face detection:  0.05695366859436035
# image shape: (480, 640, 3)
# Time of face detection:  0.052130937576293945
# image shape: (480, 640, 3)
# Time of face detection:  0.05078244209289551
# image shape: (480, 640, 3)
# Time of face detection:  0.051430702209472656
# image shape: (480, 640, 3)
# Time of face detection:  0.05088305473327637
# image shape: (480, 640, 3)
# Time of face detection:  0.05285286903381348
# image shape: (480, 640, 3)
# Time of face detection:  0.05109429359436035
# image shape: (480, 640, 3)
# Time of face detection:  0.051061391830444336
# image shape: (480, 640, 3)
# Time of face detection:  0.0502779483795166
# image shape: (480, 640, 3)
# Time of face detection:  0.052188873291015625
# image shape: (480, 640, 3)
# Time of face detection:  0.05573296546936035
# image shape: (480, 640, 3)
# Time of face detection:  0.06028413772583008
# image shape: (480, 640, 3)
# Time of face detection:  0.06296110153198242
# image shape: (480, 640, 3)
# Time of face detection:  0.049719810485839844
# image shape: (480, 640, 3)
# Time of face detection:  0.04952406883239746
# image shape: (480, 640, 3)
# Time of face detection:  0.0485692024230957
# image shape: (480, 640, 3)
# Time of face detection:  0.0647573471069336
# image shape: (480, 640, 3)
# Time of face detection:  0.06429791450500488
# image shape: (480, 640, 3)
# Time of face detection:  0.05074000358581543
# image shape: (480, 640, 3)
# Time of face detection:  0.05034160614013672
# image shape: (480, 640, 3)
# Time of face detection:  0.04993271827697754
# image shape: (480, 640, 3)
# Time of face detection:  0.050608158111572266
# image shape: (480, 640, 3)
# Time of face detection:  0.050000905990600586
# image shape: (480, 640, 3)
# Time of face detection:  0.06383085250854492
# image shape: (480, 640, 3)
# Time of face detection:  0.050049543380737305
# image shape: (480, 640, 3)
# Time of face detection:  0.051673173904418945
# image shape: (480, 640, 3)
# Time of face detection:  0.05067586898803711
# image shape: (480, 640, 3)
# Time of face detection:  0.05418801307678223
# image shape: (480, 640, 3)
# Time of face detection:  0.05008435249328613
# image shape: (480, 640, 3)
# Time of face detection:  0.050763607025146484
# image shape: (480, 640, 3)
# Time of face detection:  0.04982399940490723
# image shape: (480, 640, 3)
# Time of face detection:  0.05273151397705078
# image shape: (480, 640, 3)
# Time of face detection:  0.05065441131591797
# image shape: (480, 640, 3)
# Time of face detection:  0.05657029151916504
# image shape: (480, 640, 3)
# Time of face detection:  0.0537109375
# image shape: (480, 640, 3)
# Time of face detection:  0.05503964424133301
# image shape: (480, 640, 3)
# Time of face detection:  0.06849384307861328
# image shape: (480, 640, 3)
# Time of face detection:  0.05591249465942383
# image shape: (480, 640, 3)
# Time of face detection:  0.05597829818725586
# image shape: (480, 640, 3)
# Time of face detection:  0.050730228424072266
# image shape: (480, 640, 3)
# Time of face detection:  0.04917001724243164
# image shape: (480, 640, 3)
# Time of face detection:  0.05095553398132324
# image shape: (480, 640, 3)
# Time of face detection:  0.05635237693786621
# image shape: (480, 640, 3)
# Time of face detection:  0.058060407638549805
# image shape: (480, 640, 3)
# Time of face detection:  0.06135058403015137
# image shape: (480, 640, 3)
# Time of face detection:  0.07081007957458496
# image shape: (480, 640, 3)
# Time of face detection:  0.05625009536743164
# image shape: (480, 640, 3)
# Time of face detection:  0.05773305892944336
# image shape: (480, 640, 3)
# Time of face detection:  0.0643463134765625
# image shape: (480, 640, 3)
# Time of face detection:  0.05279660224914551
# image shape: (480, 640, 3)
# Time of face detection:  0.05545234680175781
# image shape: (480, 640, 3)
# Time of face detection:  0.054172515869140625
# image shape: (480, 640, 3)
# Time of face detection:  0.05385327339172363
# image shape: (480, 640, 3)
# Time of face detection:  0.05380988121032715
# image shape: (480, 640, 3)
# Time of face detection:  0.05103778839111328
# image shape: (480, 640, 3)
# Time of face detection:  0.054050445556640625
# image shape: (480, 640, 3)
# Time of face detection:  0.05561661720275879
# image shape: (480, 640, 3)
# Time of face detection:  0.05350375175476074
# image shape: (480, 640, 3)
# Time of face detection:  0.05035996437072754
# image shape: (480, 640, 3)
# Time of face detection:  0.06374049186706543
# image shape: (480, 640, 3)
# Time of face detection:  0.05070042610168457
# image shape: (480, 640, 3)
# Time of face detection:  0.04911398887634277
# image shape: (480, 640, 3)
# Time of face detection:  0.052190542221069336
# image shape: (480, 640, 3)
# Time of face detection:  0.061966657638549805
# image shape: (480, 640, 3)
# Time of face detection:  0.05807161331176758
# image shape: (480, 640, 3)
# Time of face detection:  0.04789328575134277
# image shape: (480, 640, 3)
# Time of face detection:  0.049001455307006836
# image shape: (480, 640, 3)
# Time of face detection:  0.047894954681396484
# image shape: (480, 640, 3)
# Time of face detection:  0.04742789268493652
# image shape: (480, 640, 3)
# Time of face detection:  0.04725050926208496
# image shape: (480, 640, 3)
# Time of face detection:  0.04752922058105469
# image shape: (480, 640, 3)
# Time of face detection:  0.04594898223876953
# image shape: (480, 640, 3)
# Time of face detection:  0.04446578025817871
# image shape: (480, 640, 3)
# Time of face detection:  0.04541182518005371
# image shape: (480, 640, 3)
# Time of face detection:  0.04407358169555664
# image shape: (480, 640, 3)
# Time of face detection:  0.044080495834350586
# image shape: (480, 640, 3)
# Time of face detection:  0.046776771545410156
# image shape: (480, 640, 3)
# Time of face detection:  0.047091007232666016
# image shape: (480, 640, 3)
# Time of face detection:  0.04691267013549805
# image shape: (480, 640, 3)
# Time of face detection:  0.05907726287841797
# image shape: (480, 640, 3)
# Time of face detection:  0.05695009231567383
# image shape: (480, 640, 3)
# Time of face detection:  0.05390429496765137
# image shape: (480, 640, 3)
# Time of face detection:  0.05308365821838379
# image shape: (480, 640, 3)
# Time of face detection:  0.051238298416137695
# image shape: (480, 640, 3)
# Time of face detection:  0.046968698501586914
# image shape: (480, 640, 3)
# Time of face detection:  0.04877901077270508
# image shape: (480, 640, 3)
# Time of face detection:  0.045145273208618164
# image shape: (480, 640, 3)
# Time of face detection:  0.04900765419006348
# image shape: (480, 640, 3)
# Time of face detection:  0.04974937438964844
# image shape: (480, 640, 3)
# Time of face detection:  0.05873394012451172
# image shape: (480, 640, 3)
# Time of face detection:  0.06009697914123535
# image shape: (480, 640, 3)
# Time of face detection:  0.050501346588134766
# image shape: (480, 640, 3)
# Time of face detection:  0.04761099815368652
# image shape: (480, 640, 3)
# Time of face detection:  0.04952216148376465
# image shape: (480, 640, 3)
# Time of face detection:  0.049158334732055664
# image shape: (480, 640, 3)
# Time of face detection:  0.04742741584777832
# image shape: (480, 640, 3)
# Time of face detection:  0.04868006706237793
# image shape: (480, 640, 3)
# Time of face detection:  0.0487062931060791
# image shape: (480, 640, 3)
# Time of face detection:  0.04807567596435547
# image shape: (480, 640, 3)
# Time of face detection:  0.048531293869018555
# image shape: (480, 640, 3)
# Time of face detection:  0.047734975814819336
# image shape: (480, 640, 3)
# Time of face detection:  0.047437191009521484
# image shape: (480, 640, 3)
# Time of face detection:  0.04748964309692383
# image shape: (480, 640, 3)
# Time of face detection:  0.046952247619628906
# image shape: (480, 640, 3)
# Time of face detection:  0.04808616638183594
# image shape: (480, 640, 3)
# Time of face detection:  0.04646730422973633
# image shape: (480, 640, 3)
# Time of face detection:  0.04836893081665039
# image shape: (480, 640, 3)
# Time of face detection:  0.04734206199645996
# image shape: (480, 640, 3)
# Time of face detection:  0.05065274238586426
# image shape: (480, 640, 3)
# Time of face detection:  0.05071735382080078
# image shape: (480, 640, 3)
# Time of face detection:  0.052947044372558594
# image shape: (480, 640, 3)
# Time of face detection:  0.05007314682006836
# image shape: (480, 640, 3)
# Time of face detection:  0.049070119857788086
# image shape: (480, 640, 3)
# Time of face detection:  0.05332207679748535
# image shape: (480, 640, 3)
# Time of face detection:  0.05020928382873535
# image shape: (480, 640, 3)
# Time of face detection:  0.0498046875
# image shape: (480, 640, 3)
# Time of face detection:  0.04794502258300781
# image shape: (480, 640, 3)
# Time of face detection:  0.048194169998168945
# image shape: (480, 640, 3)
# Time of face detection:  0.04775404930114746
# image shape: (480, 640, 3)
# Time of face detection:  0.0515596866607666
# image shape: (480, 640, 3)
# Time of face detection:  0.04656505584716797
# image shape: (480, 640, 3)
# Time of face detection:  0.04731559753417969
# image shape: (480, 640, 3)
# Time of face detection:  0.04749155044555664
# image shape: (480, 640, 3)
# Time of face detection:  0.05034017562866211
# image shape: (480, 640, 3)
# Time of face detection:  0.049744606018066406
# image shape: (480, 640, 3)
# Time of face detection:  0.06494784355163574
# image shape: (480, 640, 3)
# Time of face detection:  0.050225019454956055
# image shape: (480, 640, 3)
# Time of face detection:  0.04902935028076172
# image shape: (480, 640, 3)
# Time of face detection:  0.05006146430969238
# image shape: (480, 640, 3)
# Time of face detection:  0.053577423095703125
# image shape: (480, 640, 3)
# Time of face detection:  0.049866676330566406
# image shape: (480, 640, 3)
# Time of face detection:  0.04787158966064453
# image shape: (480, 640, 3)
# Time of face detection:  0.06257152557373047
# image shape: (480, 640, 3)
# Time of face detection:  0.04899001121520996
# image shape: (480, 640, 3)
# Time of face detection:  0.05086374282836914
# image shape: (480, 640, 3)
# Time of face detection:  0.05613851547241211
# image shape: (480, 640, 3)
# Time of face detection:  0.050650835037231445
# image shape: (480, 640, 3)
# Time of face detection:  0.046044349670410156
# image shape: (480, 640, 3)
# Time of face detection:  0.04537034034729004
# image shape: (480, 640, 3)
# Time of face detection:  0.04990077018737793
# image shape: (480, 640, 3)
# Time of face detection:  0.04860520362854004
# image shape: (480, 640, 3)
# Time of face detection:  0.052843570709228516
# image shape: (480, 640, 3)
# Time of face detection:  0.05286717414855957
# image shape: (480, 640, 3)
# Time of face detection:  0.05498766899108887
# image shape: (480, 640, 3)
# Time of face detection:  0.05589127540588379
# image shape: (480, 640, 3)
# Time of face detection:  0.05185842514038086
# image shape: (480, 640, 3)
# Time of face detection:  0.05067777633666992
# image shape: (480, 640, 3)
# Time of face detection:  0.05079817771911621
# image shape: (480, 640, 3)
# Time of face detection:  0.04975271224975586
# image shape: (480, 640, 3)
# Time of face detection:  0.04813838005065918
# image shape: (480, 640, 3)
# Time of face detection:  0.051480770111083984
# image shape: (480, 640, 3)
# Time of face detection:  0.052670955657958984
# image shape: (480, 640, 3)
# Time of face detection:  0.052149057388305664
# image shape: (480, 640, 3)
# Time of face detection:  0.048010826110839844
# image shape: (480, 640, 3)
# Time of face detection:  0.04897332191467285
# image shape: (480, 640, 3)
# Time of face detection:  0.05197739601135254
# image shape: (480, 640, 3)
# Time of face detection:  0.05009174346923828
# image shape: (480, 640, 3)
# Time of face detection:  0.04990720748901367
# image shape: (480, 640, 3)
# Time of face detection:  0.048555612564086914
# image shape: (480, 640, 3)
# Time of face detection:  0.049211978912353516
# image shape: (480, 640, 3)
# Time of face detection:  0.05084371566772461
# image shape: (480, 640, 3)
# Time of face detection:  0.05159354209899902
# image shape: (480, 640, 3)
# Time of face detection:  0.05099678039550781
# image shape: (480, 640, 3)
# Time of face detection:  0.0517578125
# image shape: (480, 640, 3)
# Time of face detection:  0.04822373390197754
# image shape: (480, 640, 3)
# Time of face detection:  0.054169416427612305
# image shape: (480, 640, 3)
# Time of face detection:  0.04919600486755371
# image shape: (480, 640, 3)
# Time of face detection:  0.047661781311035156
# image shape: (480, 640, 3)
# Time of face detection:  0.05228590965270996
# image shape: (480, 640, 3)
# Time of face detection:  0.057592153549194336
# image shape: (480, 640, 3)
# Time of face detection:  0.05865979194641113
# image shape: (480, 640, 3)
# Time of face detection:  0.05499696731567383
# image shape: (480, 640, 3)
# Time of face detection:  0.0484461784362793
# image shape: (480, 640, 3)
# Time of face detection:  0.0504305362701416
# image shape: (480, 640, 3)
# Time of face detection:  0.056272268295288086
# image shape: (480, 640, 3)
# Time of face detection:  0.052790164947509766
# image shape: (480, 640, 3)
# Time of face detection:  0.04844784736633301
# image shape: (480, 640, 3)
# Time of face detection:  0.05236959457397461
# image shape: (480, 640, 3)
# Time of face detection:  0.053263187408447266
# image shape: (480, 640, 3)
# Time of face detection:  0.054276227951049805
# image shape: (480, 640, 3)
# Time of face detection:  0.05313253402709961
# image shape: (480, 640, 3)
# Time of face detection:  0.051401376724243164
# image shape: (480, 640, 3)
# Time of face detection:  0.050160884857177734
# image shape: (480, 640, 3)
# Time of face detection:  0.04926300048828125
# image shape: (480, 640, 3)
# Time of face detection:  0.05124235153198242
# image shape: (480, 640, 3)
# Time of face detection:  0.05333089828491211
# image shape: (480, 640, 3)
# Time of face detection:  0.04968094825744629
# image shape: (480, 640, 3)
# Time of face detection:  0.05196523666381836
# image shape: (480, 640, 3)
# Time of face detection:  0.045815229415893555
# image shape: (480, 640, 3)
# Time of face detection:  0.04601740837097168
# image shape: (480, 640, 3)
# Time of face detection:  0.05205988883972168
# image shape: (480, 640, 3)
# Time of face detection:  0.04823660850524902
# image shape: (480, 640, 3)
# Time of face detection:  0.05086398124694824
# image shape: (480, 640, 3)
# Time of face detection:  0.05195808410644531
# image shape: (480, 640, 3)
# Time of face detection:  0.05036664009094238
# image shape: (480, 640, 3)
# Time of face detection:  0.05564713478088379
# image shape: (480, 640, 3)
# Time of face detection:  0.05549049377441406
# image shape: (480, 640, 3)
# Time of face detection:  0.05630803108215332
# image shape: (480, 640, 3)
# Time of face detection:  0.04941749572753906
# image shape: (480, 640, 3)
# Time of face detection:  0.046556949615478516
# image shape: (480, 640, 3)
# Time of face detection:  0.048505306243896484
# image shape: (480, 640, 3)
# Time of face detection:  0.04899954795837402
# image shape: (480, 640, 3)
# Time of face detection:  0.05032968521118164
# image shape: (480, 640, 3)
# Time of face detection:  0.051137685775756836
# image shape: (480, 640, 3)
# Time of face detection:  0.046610355377197266
# image shape: (480, 640, 3)
# Time of face detection:  0.04487442970275879
# image shape: (480, 640, 3)
# Time of face detection:  0.04503464698791504
# image shape: (480, 640, 3)
# Time of face detection:  0.0453341007232666
# image shape: (480, 640, 3)
# Time of face detection:  0.04920840263366699
# image shape: (480, 640, 3)
# Time of face detection:  0.05065011978149414
# image shape: (480, 640, 3)
# Time of face detection:  0.05202460289001465
# image shape: (480, 640, 3)
# Time of face detection:  0.04825735092163086
# image shape: (480, 640, 3)
# Time of face detection:  0.04754304885864258
# image shape: (480, 640, 3)
# Time of face detection:  0.052510976791381836
# image shape: (480, 640, 3)
# Time of face detection:  0.05367398262023926
# image shape: (480, 640, 3)
# Time of face detection:  0.06685733795166016
# image shape: (480, 640, 3)
# Time of face detection:  0.050049543380737305
# image shape: (480, 640, 3)
# Time of face detection:  0.0486292839050293
# image shape: (480, 640, 3)
# Time of face detection:  0.050704240798950195
# image shape: (480, 640, 3)
# Time of face detection:  0.04938244819641113
# image shape: (480, 640, 3)
# Time of face detection:  0.04763340950012207
# image shape: (480, 640, 3)
# Time of face detection:  0.04599928855895996
# image shape: (480, 640, 3)
# Time of face detection:  0.04642510414123535
# image shape: (480, 640, 3)
# Time of face detection:  0.049714088439941406
# image shape: (480, 640, 3)
# Time of face detection:  0.05312061309814453
# image shape: (480, 640, 3)
# Time of face detection:  0.057433128356933594
# image shape: (480, 640, 3)
# Time of face detection:  0.052018165588378906
# image shape: (480, 640, 3)
# Time of face detection:  0.049242258071899414
# image shape: (480, 640, 3)
# Time of face detection:  0.04567241668701172
# image shape: (480, 640, 3)
# Time of face detection:  0.048836708068847656
# image shape: (480, 640, 3)
# Time of face detection:  0.051048994064331055
# image shape: (480, 640, 3)
# Time of face detection:  0.050156593322753906
# image shape: (480, 640, 3)
# Time of face detection:  0.055036306381225586
# image shape: (480, 640, 3)
# Time of face detection:  0.054306983947753906
# image shape: (480, 640, 3)
# Time of face detection:  0.060979366302490234
# image shape: (480, 640, 3)
# Time of face detection:  0.058098554611206055
# image shape: (480, 640, 3)
# Time of face detection:  0.052826881408691406
# image shape: (480, 640, 3)
# Time of face detection:  0.05373096466064453
# image shape: (480, 640, 3)
# Time of face detection:  0.052573442459106445
# image shape: (480, 640, 3)
# Time of face detection:  0.056134939193725586
# image shape: (480, 640, 3)
# Time of face detection:  0.0530400276184082
# image shape: (480, 640, 3)
# Time of face detection:  0.050940513610839844
# image shape: (480, 640, 3)
# Time of face detection:  0.05166983604431152
# image shape: (480, 640, 3)
# Time of face detection:  0.05261492729187012
# image shape: (480, 640, 3)
# Time of face detection:  0.05355238914489746
# image shape: (480, 640, 3)
# Time of face detection:  0.05475878715515137
# image shape: (480, 640, 3)
# Time of face detection:  0.05493950843811035
# image shape: (480, 640, 3)
# Time of face detection:  0.05335235595703125
# image shape: (480, 640, 3)
# Time of face detection:  0.05574607849121094
# image shape: (480, 640, 3)
# Time of face detection:  0.05359029769897461
# image shape: (480, 640, 3)
# Time of face detection:  0.05498647689819336
# image shape: (480, 640, 3)
# Time of face detection:  0.05230283737182617
# image shape: (480, 640, 3)
# Time of face detection:  0.05455160140991211
# image shape: (480, 640, 3)
# Time of face detection:  0.05408143997192383
# image shape: (480, 640, 3)
# Time of face detection:  0.05173993110656738
# image shape: (480, 640, 3)
# Time of face detection:  0.05077838897705078
# image shape: (480, 640, 3)
# Time of face detection:  0.05430960655212402
# image shape: (480, 640, 3)
# Time of face detection:  0.053287506103515625
# image shape: (480, 640, 3)
# Time of face detection:  0.053083181381225586
# image shape: (480, 640, 3)
# Time of face detection:  0.05929398536682129
# image shape: (480, 640, 3)
# Time of face detection:  0.05523204803466797
# image shape: (480, 640, 3)
# Time of face detection:  0.049800872802734375
# image shape: (480, 640, 3)
# Time of face detection:  0.05231142044067383
# image shape: (480, 640, 3)
# Time of face detection:  0.05114865303039551
# image shape: (480, 640, 3)
# Time of face detection:  0.05494809150695801
# image shape: (480, 640, 3)
# Time of face detection:  0.06156134605407715
# image shape: (480, 640, 3)
# Time of face detection:  0.05937957763671875
# image shape: (480, 640, 3)
# Time of face detection:  0.05664777755737305
# image shape: (480, 640, 3)
# Time of face detection:  0.06604552268981934
# image shape: (480, 640, 3)
# Time of face detection:  0.05714607238769531
# image shape: (480, 640, 3)
# Time of face detection:  0.055838823318481445
# image shape: (480, 640, 3)
# Time of face detection:  0.05354166030883789
# image shape: (480, 640, 3)
# Time of face detection:  0.057141780853271484
# image shape: (480, 640, 3)
# Time of face detection:  0.06954836845397949
# image shape: (480, 640, 3)
# Time of face detection:  0.057843685150146484
# image shape: (480, 640, 3)
# Time of face detection:  0.05484485626220703
# image shape: (480, 640, 3)
# Time of face detection:  0.052550554275512695
# image shape: (480, 640, 3)
# Time of face detection:  0.053314208984375
# image shape: (480, 640, 3)
# Time of face detection:  0.0524296760559082
# image shape: (480, 640, 3)
# Time of face detection:  0.05340743064880371
# image shape: (480, 640, 3)
# Time of face detection:  0.052205562591552734
# image shape: (480, 640, 3)
# Time of face detection:  0.05639076232910156
# image shape: (480, 640, 3)
# Time of face detection:  0.05860257148742676
# image shape: (480, 640, 3)
# Time of face detection:  0.05876445770263672
# image shape: (480, 640, 3)
# Time of face detection:  0.057186126708984375
# image shape: (480, 640, 3)
# Time of face detection:  0.05145692825317383
# image shape: (480, 640, 3)
# Time of face detection:  0.05138063430786133
# image shape: (480, 640, 3)
# Time of face detection:  0.057776689529418945
# image shape: (480, 640, 3)
# Time of face detection:  0.05679178237915039
# image shape: (480, 640, 3)
# Time of face detection:  0.054238080978393555
# image shape: (480, 640, 3)
# Time of face detection:  0.05533242225646973
# image shape: (480, 640, 3)
# Time of face detection:  0.05933046340942383
# image shape: (480, 640, 3)
# Time of face detection:  0.05479240417480469
# image shape: (480, 640, 3)
# Time of face detection:  0.05666041374206543
# image shape: (480, 640, 3)
# Time of face detection:  0.05749034881591797
# image shape: (480, 640, 3)
# Time of face detection:  0.05371689796447754
# image shape: (480, 640, 3)
# Time of face detection:  0.05860614776611328
# image shape: (480, 640, 3)
# Time of face detection:  0.05540132522583008
# image shape: (480, 640, 3)
# Time of face detection:  0.0533597469329834
# image shape: (480, 640, 3)
# Time of face detection:  0.06454777717590332
# image shape: (480, 640, 3)
# Time of face detection:  0.07232332229614258
# image shape: (480, 640, 3)
# Time of face detection:  0.057669639587402344
# image shape: (480, 640, 3)
# Time of face detection:  0.052550554275512695
# image shape: (480, 640, 3)
# Time of face detection:  0.053513526916503906
# image shape: (480, 640, 3)
# Time of face detection:  0.05097317695617676
# image shape: (480, 640, 3)
# Time of face detection:  0.05047321319580078
# image shape: (480, 640, 3)
# Time of face detection:  0.05038952827453613
# image shape: (480, 640, 3)
# Time of face detection:  0.050701141357421875
# image shape: (480, 640, 3)
# Time of face detection:  0.05214738845825195
# image shape: (480, 640, 3)
# Time of face detection:  0.06412267684936523
# image shape: (480, 640, 3)
# Time of face detection:  0.06200122833251953
# image shape: (480, 640, 3)
# Time of face detection:  0.05120277404785156
# image shape: (480, 640, 3)
# Time of face detection:  0.05016922950744629
# image shape: (480, 640, 3)
# Time of face detection:  0.05044293403625488
# image shape: (480, 640, 3)
# Time of face detection:  0.05197501182556152
# image shape: (480, 640, 3)
# Time of face detection:  0.05183696746826172
# image shape: (480, 640, 3)
# Time of face detection:  0.057944297790527344
# image shape: (480, 640, 3)
# Time of face detection:  0.05547690391540527
# image shape: (480, 640, 3)
# Time of face detection:  0.05657696723937988
# image shape: (480, 640, 3)
# Time of face detection:  0.05741477012634277
# image shape: (480, 640, 3)
# Time of face detection:  0.0531766414642334
# image shape: (480, 640, 3)
# Time of face detection:  0.05494284629821777
# image shape: (480, 640, 3)
# Time of face detection:  0.05396270751953125
# image shape: (480, 640, 3)
# Time of face detection:  0.05413818359375
# image shape: (480, 640, 3)
# Time of face detection:  0.05219769477844238
# image shape: (480, 640, 3)
# Time of face detection:  0.054308176040649414
# image shape: (480, 640, 3)
# Time of face detection:  0.05602216720581055
# image shape: (480, 640, 3)
# Time of face detection:  0.052469491958618164
# image shape: (480, 640, 3)
# Time of face detection:  0.05273580551147461
# image shape: (480, 640, 3)
# Time of face detection:  0.054967403411865234
# image shape: (480, 640, 3)
# Time of face detection:  0.06177020072937012
# image shape: (480, 640, 3)
# Time of face detection:  0.0657510757446289
# image shape: (480, 640, 3)
# Time of face detection:  0.06187629699707031
# image shape: (480, 640, 3)
# Time of face detection:  0.05930900573730469
# image shape: (480, 640, 3)
# Time of face detection:  0.055036067962646484
# image shape: (480, 640, 3)
# Time of face detection:  0.058162689208984375
# image shape: (480, 640, 3)
# Time of face detection:  0.05786538124084473
# image shape: (480, 640, 3)
# Time of face detection:  0.053411006927490234
# image shape: (480, 640, 3)
# Time of face detection:  0.06119346618652344
# image shape: (480, 640, 3)
# Time of face detection:  0.06775736808776855
# image shape: (480, 640, 3)
# Time of face detection:  0.07053256034851074
# image shape: (480, 640, 3)
# Time of face detection:  0.07320046424865723
# image shape: (480, 640, 3)
# Time of face detection:  0.05485343933105469
# image shape: (480, 640, 3)
# Time of face detection:  0.05364084243774414
# image shape: (480, 640, 3)
# Time of face detection:  0.05746126174926758
# image shape: (480, 640, 3)
# Time of face detection:  0.053650856018066406
# image shape: (480, 640, 3)
# Time of face detection:  0.058508872985839844
# image shape: (480, 640, 3)
# Time of face detection:  0.053574323654174805
# image shape: (480, 640, 3)
# Time of face detection:  0.05556845664978027
# image shape: (480, 640, 3)
# Time of face detection:  0.06127119064331055
# image shape: (480, 640, 3)
# Time of face detection:  0.06815600395202637
# image shape: (480, 640, 3)
# Time of face detection:  0.05124807357788086
# image shape: (480, 640, 3)
# Time of face detection:  0.05230712890625
# image shape: (480, 640, 3)
# Time of face detection:  0.052530527114868164
# image shape: (480, 640, 3)
# Time of face detection:  0.05761528015136719
# image shape: (480, 640, 3)
# Time of face detection:  0.05007600784301758
# image shape: (480, 640, 3)
# Time of face detection:  0.0523226261138916
# image shape: (480, 640, 3)
# Time of face detection:  0.054743289947509766
# image shape: (480, 640, 3)
# Time of face detection:  0.053682804107666016
# image shape: (480, 640, 3)
# Time of face detection:  0.04981660842895508
# image shape: (480, 640, 3)
# Time of face detection:  0.0639486312866211
# image shape: (480, 640, 3)
# Time of face detection:  0.07056045532226562
# image shape: (480, 640, 3)
# Time of face detection:  0.0494384765625
# image shape: (480, 640, 3)
# Time of face detection:  0.07540631294250488
# image shape: (480, 640, 3)
# Time of face detection:  0.05092215538024902
# image shape: (480, 640, 3)
# Time of face detection:  0.052248477935791016
# image shape: (480, 640, 3)
# Time of face detection:  0.05018472671508789
# image shape: (480, 640, 3)
# Time of face detection:  0.05338144302368164
# image shape: (480, 640, 3)
# Time of face detection:  0.05115199089050293
# image shape: (480, 640, 3)
# Time of face detection:  0.05623674392700195
# image shape: (480, 640, 3)
# Time of face detection:  0.0538027286529541
# image shape: (480, 640, 3)
# Time of face detection:  0.051863908767700195
# image shape: (480, 640, 3)
# Time of face detection:  0.051198720932006836
# image shape: (480, 640, 3)
# Time of face detection:  0.07305574417114258
# image shape: (480, 640, 3)
# Time of face detection:  0.05138254165649414
# image shape: (480, 640, 3)
# Time of face detection:  0.05092620849609375
# image shape: (480, 640, 3)
# Time of face detection:  0.05138874053955078
# image shape: (480, 640, 3)
# Time of face detection:  0.05591940879821777
# image shape: (480, 640, 3)
# Time of face detection:  0.05684947967529297
# image shape: (480, 640, 3)
# Time of face detection:  0.053563594818115234
# image shape: (480, 640, 3)
# Time of face detection:  0.05490851402282715
# image shape: (480, 640, 3)
# Time of face detection:  0.05722618103027344
# image shape: (480, 640, 3)
# Time of face detection:  0.07712793350219727
# image shape: (480, 640, 3)
# Time of face detection:  0.06073164939880371
# image shape: (480, 640, 3)
# Time of face detection:  0.05879092216491699
# image shape: (480, 640, 3)
# Time of face detection:  0.07669401168823242
# image shape: (480, 640, 3)
# Time of face detection:  0.0527498722076416
# image shape: (480, 640, 3)
# Time of face detection:  0.05171012878417969
# image shape: (480, 640, 3)
# Time of face detection:  0.051605939865112305
# image shape: (480, 640, 3)
# Time of face detection:  0.05348801612854004
# image shape: (480, 640, 3)
# Time of face detection:  0.06083059310913086
# image shape: (480, 640, 3)
# Time of face detection:  0.06664824485778809
# image shape: (480, 640, 3)
# Time of face detection:  0.054306983947753906
# image shape: (480, 640, 3)
# Time of face detection:  0.05010700225830078
# image shape: (480, 640, 3)
# Time of face detection:  0.0505986213684082
# image shape: (480, 640, 3)
# Time of face detection:  0.05060386657714844
# image shape: (480, 640, 3)
# Time of face detection:  0.050412654876708984
# image shape: (480, 640, 3)
# Time of face detection:  0.054205894470214844
# image shape: (480, 640, 3)
# Time of face detection:  0.05798006057739258
# image shape: (480, 640, 3)
# Time of face detection:  0.05561327934265137
# image shape: (480, 640, 3)
# Time of face detection:  0.05557107925415039
# image shape: (480, 640, 3)
# Time of face detection:  0.05386614799499512
# image shape: (480, 640, 3)
# Time of face detection:  0.05063199996948242
# image shape: (480, 640, 3)
# Time of face detection:  0.051337242126464844
# image shape: (480, 640, 3)
# Time of face detection:  0.05102658271789551
# image shape: (480, 640, 3)
# Time of face detection:  0.054262399673461914
# image shape: (480, 640, 3)
# Time of face detection:  0.053119659423828125
# image shape: (480, 640, 3)
# Time of face detection:  0.05133771896362305
# image shape: (480, 640, 3)
# Time of face detection:  0.05306720733642578
# image shape: (480, 640, 3)
# Time of face detection:  0.054147958755493164
# image shape: (480, 640, 3)
# Time of face detection:  0.052750587463378906
# image shape: (480, 640, 3)
# Time of face detection:  0.05486774444580078
# image shape: (480, 640, 3)
# Time of face detection:  0.06331849098205566
# image shape: (480, 640, 3)
# Time of face detection:  0.051946163177490234
# image shape: (480, 640, 3)
# Time of face detection:  0.052481651306152344
# image shape: (480, 640, 3)
# Time of face detection:  0.052588462829589844
# image shape: (480, 640, 3)
# Time of face detection:  0.05409693717956543
# image shape: (480, 640, 3)
# Time of face detection:  0.05385541915893555
# image shape: (480, 640, 3)
# Time of face detection:  0.0571894645690918
# image shape: (480, 640, 3)
# Time of face detection:  0.05139017105102539
# image shape: (480, 640, 3)
# Time of face detection:  0.052704811096191406
# image shape: (480, 640, 3)
# Time of face detection:  0.052697181701660156
# image shape: (480, 640, 3)
# Time of face detection:  0.053691864013671875
# image shape: (480, 640, 3)
# Time of face detection:  0.057775259017944336
# image shape: (480, 640, 3)
# Time of face detection:  0.0654757022857666
# image shape: (480, 640, 3)
# Time of face detection:  0.058376312255859375
# image shape: (480, 640, 3)
# Time of face detection:  0.05055403709411621
# image shape: (480, 640, 3)
# Time of face detection:  0.05713605880737305
# image shape: (480, 640, 3)
# Time of face detection:  0.050805091857910156
# image shape: (480, 640, 3)
# Time of face detection:  0.04611563682556152
# image shape: (480, 640, 3)
# Time of face detection:  0.044975996017456055
# image shape: (480, 640, 3)
# Time of face detection:  0.05023765563964844
# image shape: (480, 640, 3)
# Time of face detection:  0.05055642127990723
# image shape: (480, 640, 3)
# Time of face detection:  0.060628414154052734
# image shape: (480, 640, 3)
# Time of face detection:  0.05895709991455078
# image shape: (480, 640, 3)
# Time of face detection:  0.05621695518493652
# image shape: (480, 640, 3)
# Time of face detection:  0.04938626289367676
# image shape: (480, 640, 3)
# Time of face detection:  0.048943281173706055
# image shape: (480, 640, 3)
# Time of face detection:  0.04817843437194824
# image shape: (480, 640, 3)
# Time of face detection:  0.04803824424743652
# image shape: (480, 640, 3)
# Time of face detection:  0.04926943778991699
# image shape: (480, 640, 3)
# Time of face detection:  0.04977297782897949
# image shape: (480, 640, 3)
# Time of face detection:  0.058914899826049805
# image shape: (480, 640, 3)
# Time of face detection:  0.04685330390930176
# image shape: (480, 640, 3)
# Time of face detection:  0.04939436912536621
# image shape: (480, 640, 3)
# Time of face detection:  0.04845857620239258
# image shape: (480, 640, 3)
# Time of face detection:  0.049199819564819336
# image shape: (480, 640, 3)
# Time of face detection:  0.04644370079040527
# image shape: (480, 640, 3)
# Time of face detection:  0.07111811637878418
# image shape: (480, 640, 3)
# Time of face detection:  0.04596877098083496
# image shape: (480, 640, 3)
# Time of face detection:  0.04691195487976074
# image shape: (480, 640, 3)
# Time of face detection:  0.05441761016845703
# image shape: (480, 640, 3)
# Time of face detection:  0.05727076530456543
# image shape: (480, 640, 3)
# Time of face detection:  0.06078338623046875
# image shape: (480, 640, 3)
# Time of face detection:  0.05322575569152832
# image shape: (480, 640, 3)
# Time of face detection:  0.05605459213256836
# image shape: (480, 640, 3)
# Time of face detection:  0.056025028228759766
# image shape: (480, 640, 3)
# Time of face detection:  0.06201362609863281
# image shape: (480, 640, 3)
# Time of face detection:  0.05992746353149414
# image shape: (480, 640, 3)
# Time of face detection:  0.05302619934082031
# image shape: (480, 640, 3)
# Time of face detection:  0.0558929443359375
# image shape: (480, 640, 3)
# Time of face detection:  0.05507469177246094
# image shape: (480, 640, 3)
# Time of face detection:  0.056134939193725586
# image shape: (480, 640, 3)
# Time of face detection:  0.053785085678100586
# image shape: (480, 640, 3)
# Time of face detection:  0.05357241630554199
# image shape: (480, 640, 3)
# Time of face detection:  0.0560915470123291
# image shape: (480, 640, 3)
# Time of face detection:  0.05325579643249512
# image shape: (480, 640, 3)
# Time of face detection:  0.07142305374145508
# image shape: (480, 640, 3)
# Time of face detection:  0.06195497512817383
# image shape: (480, 640, 3)
# Time of face detection:  0.05808234214782715
# image shape: (480, 640, 3)
# Time of face detection:  0.0497281551361084
# image shape: (480, 640, 3)
# Time of face detection:  0.048666954040527344
# image shape: (480, 640, 3)
# Time of face detection:  0.0536191463470459
# image shape: (480, 640, 3)
# Time of face detection:  0.06289529800415039
# image shape: (480, 640, 3)
# Time of face detection:  0.05595850944519043
# image shape: (480, 640, 3)
# Time of face detection:  0.0605928897857666
# image shape: (480, 640, 3)
# Time of face detection:  0.06333756446838379
# image shape: (480, 640, 3)
# Time of face detection:  0.06403636932373047
# image shape: (480, 640, 3)
# Time of face detection:  0.05673670768737793
# image shape: (480, 640, 3)
# Time of face detection:  0.05253887176513672
