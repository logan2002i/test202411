# %%
import os
import cv2
# from mtcnn import MTCNN
from mtcnn_cv2 import MTCNN
detector = MTCNN()

# %%
def extract_file(path):
    #path 圖片資料夾絕對路徑
    pach_list = []
    if os.path.isdir(path) == True:
            for r, d, f in os.walk(path): # r=root, d=directories, f = files
                for file in f:
                    if ('.jpg' in file):
                        exact_path = r + "/" + file
                        pach_list.append(exact_path)
#                         print(exact_path)
                    else:
                        print("沒照片")
    return pach_list

# %%
def mtcnn_process(img_path, save_path,file):
    '''
    #MTCNN bounding box 說明
    #回傳四個參數   x1, y1, w, h
    # x1, y1為起始座標 , w為x軸長度 , h為y軸長
    opencv 裁切為[y起始:y結束, x起始:x結束]
    '''
    # img_path 圖片絕對路徑
    # save_path 放圖片資料夾路徑
    # years 年齡
    # file 圖檔名稱
    detector = MTCNN()
    test_pic = img_path
    image = cv2.cvtColor(cv2.imread(test_pic), cv2.COLOR_BGR2RGB)
    result = detector.detect_faces(image)
#     print(img_path)
#     print(result)
    if len(result)<0:
        print("偵測不到傻眼")
        print(img_path+"偵測不到傻眼")
        print(result[0]['box'])
    if len(result) > 0:
        bounding_box = result[0]['box']

        crop_img = image[bounding_box[1]:bounding_box[1]+bounding_box[3], bounding_box[0]:bounding_box[0]+bounding_box[2]]
        resize_img = cv2.resize(crop_img,(112,112))
#         if years == None:
        cv2.imwrite(save_path+'/'+file, cv2.cvtColor(resize_img, cv2.COLOR_RGB2BGR))
#         else:
#         cv2.imwrite(save_path+'/'+str(years)+'_'+file, cv2.cvtColor(resize_img, cv2.COLOR_RGB2BGR))

# %%
# file_list = extract_file('D:/Allen/AIFR/MTLFace-master/preprocess/2022_Pose_face/Ting/Base/')
file_list = extract_file('D:/Jerry/webcam/Dataset/')

# %%
file_list
# Out:
# ['D:/Jerry/webcam/Dataset//demo_1.jpg',
#  'D:/Jerry/webcam/Dataset//demo_10.jpg',
#  'D:/Jerry/webcam/Dataset//demo_100.jpg',
#  'D:/Jerry/webcam/Dataset//demo_101.jpg',
#  'D:/Jerry/webcam/Dataset//demo_102.jpg',
#  'D:/Jerry/webcam/Dataset//demo_103.jpg',
#  'D:/Jerry/webcam/Dataset//demo_104.jpg',
#  'D:/Jerry/webcam/Dataset//demo_105.jpg',
#  'D:/Jerry/webcam/Dataset//demo_106.jpg',
#  'D:/Jerry/webcam/Dataset//demo_107.jpg',
#  'D:/Jerry/webcam/Dataset//demo_108.jpg',
#  'D:/Jerry/webcam/Dataset//demo_109.jpg',
#  'D:/Jerry/webcam/Dataset//demo_11.jpg',
#  'D:/Jerry/webcam/Dataset//demo_110.jpg',
#  'D:/Jerry/webcam/Dataset//demo_111.jpg',
#  'D:/Jerry/webcam/Dataset//demo_112.jpg',
#  'D:/Jerry/webcam/Dataset//demo_113.jpg',
#  'D:/Jerry/webcam/Dataset//demo_114.jpg',
#  'D:/Jerry/webcam/Dataset//demo_115.jpg',
#  'D:/Jerry/webcam/Dataset//demo_116.jpg',
#  'D:/Jerry/webcam/Dataset//demo_117.jpg',
#  'D:/Jerry/webcam/Dataset//demo_118.jpg',
#  'D:/Jerry/webcam/Dataset//demo_119.jpg',
#  'D:/Jerry/webcam/Dataset//demo_12.jpg',
#  'D:/Jerry/webcam/Dataset//demo_120.jpg',
#  'D:/Jerry/webcam/Dataset//demo_121.jpg',
#  'D:/Jerry/webcam/Dataset//demo_122.jpg',
#  'D:/Jerry/webcam/Dataset//demo_123.jpg',
#  'D:/Jerry/webcam/Dataset//demo_124.jpg',
#  'D:/Jerry/webcam/Dataset//demo_125.jpg',
#  'D:/Jerry/webcam/Dataset//demo_126.jpg',
#  'D:/Jerry/webcam/Dataset//demo_127.jpg',
#  'D:/Jerry/webcam/Dataset//demo_128.jpg',
#  'D:/Jerry/webcam/Dataset//demo_129.jpg',
#  'D:/Jerry/webcam/Dataset//demo_13.jpg',
#  'D:/Jerry/webcam/Dataset//demo_130.jpg',
#  'D:/Jerry/webcam/Dataset//demo_131.jpg',
#  'D:/Jerry/webcam/Dataset//demo_132.jpg',
#  'D:/Jerry/webcam/Dataset//demo_133.jpg',
#  'D:/Jerry/webcam/Dataset//demo_134.jpg',
#  'D:/Jerry/webcam/Dataset//demo_14.jpg',
#  'D:/Jerry/webcam/Dataset//demo_15.jpg',
#  'D:/Jerry/webcam/Dataset//demo_16.jpg',
#  'D:/Jerry/webcam/Dataset//demo_17.jpg',
#  'D:/Jerry/webcam/Dataset//demo_18.jpg',
#  'D:/Jerry/webcam/Dataset//demo_19.jpg',
#  'D:/Jerry/webcam/Dataset//demo_2.jpg',
#  'D:/Jerry/webcam/Dataset//demo_20.jpg',
#  'D:/Jerry/webcam/Dataset//demo_21.jpg',
#  'D:/Jerry/webcam/Dataset//demo_22.jpg',
#  'D:/Jerry/webcam/Dataset//demo_23.jpg',
#  'D:/Jerry/webcam/Dataset//demo_24.jpg',
#  'D:/Jerry/webcam/Dataset//demo_25.jpg',
#  'D:/Jerry/webcam/Dataset//demo_26.jpg',
#  'D:/Jerry/webcam/Dataset//demo_27.jpg',
#  'D:/Jerry/webcam/Dataset//demo_28.jpg',
#  'D:/Jerry/webcam/Dataset//demo_29.jpg',
#  'D:/Jerry/webcam/Dataset//demo_3.jpg',
#  'D:/Jerry/webcam/Dataset//demo_30.jpg',
#  'D:/Jerry/webcam/Dataset//demo_31.jpg',
#  'D:/Jerry/webcam/Dataset//demo_32.jpg',
#  'D:/Jerry/webcam/Dataset//demo_33.jpg',
#  'D:/Jerry/webcam/Dataset//demo_34.jpg',
#  'D:/Jerry/webcam/Dataset//demo_35.jpg',
#  'D:/Jerry/webcam/Dataset//demo_36.jpg',
#  'D:/Jerry/webcam/Dataset//demo_37.jpg',
#  'D:/Jerry/webcam/Dataset//demo_38.jpg',
#  'D:/Jerry/webcam/Dataset//demo_39.jpg',
#  'D:/Jerry/webcam/Dataset//demo_4.jpg',
#  'D:/Jerry/webcam/Dataset//demo_40.jpg',
#  'D:/Jerry/webcam/Dataset//demo_41.jpg',
#  'D:/Jerry/webcam/Dataset//demo_42.jpg',
#  'D:/Jerry/webcam/Dataset//demo_43.jpg',
#  'D:/Jerry/webcam/Dataset//demo_44.jpg',
#  'D:/Jerry/webcam/Dataset//demo_45.jpg',
#  'D:/Jerry/webcam/Dataset//demo_46.jpg',
#  'D:/Jerry/webcam/Dataset//demo_47.jpg',
#  'D:/Jerry/webcam/Dataset//demo_48.jpg',
#  'D:/Jerry/webcam/Dataset//demo_49.jpg',
#  'D:/Jerry/webcam/Dataset//demo_5.jpg',
#  'D:/Jerry/webcam/Dataset//demo_50.jpg',
#  'D:/Jerry/webcam/Dataset//demo_51.jpg',
#  'D:/Jerry/webcam/Dataset//demo_52.jpg',
#  'D:/Jerry/webcam/Dataset//demo_53.jpg',
#  'D:/Jerry/webcam/Dataset//demo_54.jpg',
#  'D:/Jerry/webcam/Dataset//demo_55.jpg',
#  'D:/Jerry/webcam/Dataset//demo_56.jpg',
#  'D:/Jerry/webcam/Dataset//demo_57.jpg',
#  'D:/Jerry/webcam/Dataset//demo_58.jpg',
#  'D:/Jerry/webcam/Dataset//demo_59.jpg',
#  'D:/Jerry/webcam/Dataset//demo_6.jpg',
#  'D:/Jerry/webcam/Dataset//demo_60.jpg',
#  'D:/Jerry/webcam/Dataset//demo_61.jpg',
#  'D:/Jerry/webcam/Dataset//demo_62.jpg',
#  'D:/Jerry/webcam/Dataset//demo_63.jpg',
#  'D:/Jerry/webcam/Dataset//demo_64.jpg',
#  'D:/Jerry/webcam/Dataset//demo_65.jpg',
#  'D:/Jerry/webcam/Dataset//demo_66.jpg',
#  'D:/Jerry/webcam/Dataset//demo_67.jpg',
#  'D:/Jerry/webcam/Dataset//demo_68.jpg',
#  'D:/Jerry/webcam/Dataset//demo_69.jpg',
#  'D:/Jerry/webcam/Dataset//demo_7.jpg',
#  'D:/Jerry/webcam/Dataset//demo_70.jpg',
#  'D:/Jerry/webcam/Dataset//demo_71.jpg',
#  'D:/Jerry/webcam/Dataset//demo_72.jpg',
#  'D:/Jerry/webcam/Dataset//demo_73.jpg',
#  'D:/Jerry/webcam/Dataset//demo_74.jpg',
#  'D:/Jerry/webcam/Dataset//demo_75.jpg',
#  'D:/Jerry/webcam/Dataset//demo_76.jpg',
#  'D:/Jerry/webcam/Dataset//demo_77.jpg',
#  'D:/Jerry/webcam/Dataset//demo_78.jpg',
#  'D:/Jerry/webcam/Dataset//demo_79.jpg',
#  'D:/Jerry/webcam/Dataset//demo_8.jpg',
#  'D:/Jerry/webcam/Dataset//demo_80.jpg',
#  'D:/Jerry/webcam/Dataset//demo_81.jpg',
#  'D:/Jerry/webcam/Dataset//demo_82.jpg',
#  'D:/Jerry/webcam/Dataset//demo_83.jpg',
#  'D:/Jerry/webcam/Dataset//demo_84.jpg',
#  'D:/Jerry/webcam/Dataset//demo_85.jpg',
#  'D:/Jerry/webcam/Dataset//demo_86.jpg',
#  'D:/Jerry/webcam/Dataset//demo_87.jpg',
#  'D:/Jerry/webcam/Dataset//demo_88.jpg',
#  'D:/Jerry/webcam/Dataset//demo_89.jpg',
#  'D:/Jerry/webcam/Dataset//demo_9.jpg',
#  'D:/Jerry/webcam/Dataset//demo_90.jpg',
#  'D:/Jerry/webcam/Dataset//demo_91.jpg',
#  'D:/Jerry/webcam/Dataset//demo_92.jpg',
#  'D:/Jerry/webcam/Dataset//demo_93.jpg',
#  'D:/Jerry/webcam/Dataset//demo_94.jpg',
#  'D:/Jerry/webcam/Dataset//demo_95.jpg',
#  'D:/Jerry/webcam/Dataset//demo_96.jpg',
#  'D:/Jerry/webcam/Dataset//demo_97.jpg',
#  'D:/Jerry/webcam/Dataset//demo_98.jpg',
#  'D:/Jerry/webcam/Dataset//demo_99.jpg']

# %%
if (len(file_list) != 0):
    for i in file_list:
#         mtcnn_process(i, 'D:/Allen/AIFR/MTLFace-master/preprocess/2022_Pose_face/Ting/Base/processed/',os.path.split(i)[1])
        mtcnn_process(i, 'D:/Jerry/webcam/dected/',os.path.split(i)[1])

# %% [markdown]
# # 沒有年齡版

# %%
def mtcnn_process_noyear(img_path, save_path, years, file):
    '''
    #MTCNN bounding box 說明
    #回傳四個參數   x1, y1, w, h
    # x1, y1為起始座標 , w為x軸長度 , h為y軸長
    opencv 裁切為[y起始:y結束, x起始:x結束]
    '''
    # img_path 圖片絕對路徑
    # save_path 放圖片資料夾路徑
    # years 年齡
    # file 圖檔名稱
    detector = MTCNN()
    test_pic = img_path
    image = cv2.cvtColor(cv2.imread(test_pic), cv2.COLOR_BGR2RGB)
    result = detector.detect_faces(image)
#     print(img_path)
#     print(result)
    if len(result)<0:
        print("偵測不到傻眼")
        print(img_path+"偵測不到傻眼")
        print(result[0]['box'])
    if len(result) > 0:
        bounding_box = result[0]['box']

        crop_img = image[bounding_box[1]:bounding_box[1]+bounding_box[3], bounding_box[0]:bounding_box[0]+bounding_box[2]]
        resize_img = cv2.resize(crop_img,(112,112))
#         if years == None:
#         cv2.imwrite(save_path+'/'+file, cv2.cvtColor(resize_img, cv2.COLOR_RGB2BGR))
#         else:
        cv2.imwrite(save_path+'/'+str(years)+'_'+file, cv2.cvtColor(resize_img, cv2.COLOR_RGB2BGR))

# %%
file_list = extract_file('D:/Allen/AIFR/MTLFace-master/preprocess/2022Allen_dataset/Ting/20211126/center')
if (len(file_list) != 0):
    for i in file_list:
        mtcnn_process_noyear(i, 'D:/Allen/AIFR/MTLFace-master/preprocess/2022Allen_dataset/ss', 20, os.path.split(i)[1])
